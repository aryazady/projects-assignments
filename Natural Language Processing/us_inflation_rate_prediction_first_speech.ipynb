# %% [markdown]
# # 1. Packages

# %%
import pandas as pd
import re
import nltk
import spacy
import numpy as np
from nltk.corpus import inaugural
from spacy.tokens import Token
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from gensim.models import Word2Vec
from sklearn.svm import SVR, SVC
from sklearn.model_selection import train_test_split, GridSearchCV, RepeatedKFold
from sklearn.metrics import mean_squared_error, f1_score

nltk.download('all-nltk', quiet=True)

nlp = spacy.load('en_core_web_sm')
future_getter = lambda token: token.text in ("will", "going", "shall")
Token.set_extension("is_future", getter=future_getter)

# %% [markdown]
# # 2. Preprocessing

# %%
def get_tenses_count(doc):
  past = 0
  present = 0
  future = 0
  all = 0
  for token in doc:
    tense = token.morph.get('Tense')
    if tense:
      if tense[0] == 'Past':
        past += 1
        all += 1
      elif tense[0] == 'Pres':
        present += 1
        all += 1
    if token._.is_future:
      future += 1
      all += 1
  return past / all, present / all, future / all

def get_pos_count(doc):
  nn = 0
  vrb = 0
  adj = 0
  adv = 0
  all = 0
  for token in doc:
    pos = token.pos_
    if pos == 'NOUN':
      nn += 1
      all += 1
    elif pos == 'VERB':
      vrb += 1
      all += 1
    elif pos == 'ADJ':
      adj += 1
      all += 1
    elif pos == 'ADV':
      adv += 1
      all += 1
  return  nn / all, vrb / all, (adj + adv) / all

def sentence_statistics(doc):
  length = []
  for s in doc.sents:
    length.append(len(s))
  length = np.array(length)
  return np.min(length), np.max(length), np.mean(length), np.median(length)

def preprocessing(nlp, doc):
  new_doc = []
  for token in doc:
    if not (token.is_stop or token.is_punct or (not token.is_ascii) or token._.is_future or len(token.text) < 2):
      new_doc.append(token.lemma_)
  return nlp(' '.join(new_doc))


data = {}
data_raw = {}
data_w2v = []
data_w2v_raw = []
for speech in inaugural.fileids():
  text = inaugural.raw(speech).lower()
  text_raw = text
  text = re.sub('\d\dth|\dth|1st|2nd|3rd', '', text)
  text = re.sub('(¡x)|¨|â|¡', '', text)
  text = re.sub('\s{1,}', ' ', text)
  doc = nlp(text)
  doc_raw = nlp(text_raw)
  data_w2v_raw += [[t.lemma_ for t in s] for s in doc_raw.sents]
  past, pres, future = get_tenses_count(doc)
  past_raw, pres_raw, future_raw = get_tenses_count(doc_raw)
  min_, max_, mean, median = sentence_statistics(doc)
  min_raw, max_raw, mean_raw, median_raw = sentence_statistics(doc_raw)
  noun, verb, ad = get_pos_count(doc)
  noun_raw, verb_raw, ad_raw = get_pos_count(doc_raw)
  doc = preprocessing(nlp, doc)
  data_w2v += [[t.lemma_ for t in s] for s in doc.sents]
  frequent_words = nltk.FreqDist([token.text for token in doc]).most_common(5)
  frequent_words_raw = nltk.FreqDist([token.text for token in doc_raw]).most_common(5)
  data[speech.split('.')[0]] = {'noun': noun, 'verb': verb, 'adj': ad,
                                'past': past, 'pres': pres, 'future': future,
                                'min': min_, 'max': max_, 'mean': mean.round(2), 'median': median,
                                '1st_freq': frequent_words[0][0], '2nd_freq': frequent_words[1][0],
                                '3rd_freq': frequent_words[2][0], '4th_freq': frequent_words[3][0],
                                '5th_freq': frequent_words[4][0]}
  
  data_raw[speech.split('.')[0]] = {'noun': noun_raw, 'verb': verb_raw, 'adj': ad_raw,
                                'past': past_raw, 'pres': pres_raw, 'future': future_raw,
                                'min': min_raw, 'max': max_raw, 'mean': mean_raw.round(2), 'median': median_raw,
                                '1st_freq': frequent_words_raw[0][0], '2nd_freq': frequent_words_raw[1][0],
                                '3rd_freq': frequent_words_raw[2][0], '4th_freq': frequent_words_raw[3][0],
                                '5th_freq': frequent_words_raw[4][0]}

# %% [markdown]
# # 3. Creating DataFrame

# %%
df = pd.DataFrame.from_dict(data, orient='index')
df.head()
# Out:
#                      noun      verb       adj      past      pres    future  \
# 1789-Washington  0.469841  0.230159  0.300000  0.490066  0.423841  0.086093
# 1793-Washington  0.464286  0.232143  0.303571  0.312500  0.500000  0.187500
# 1797-Adams       0.554275  0.166186  0.279539  0.598901  0.368132  0.032967
# 1801-Jefferson   0.493719  0.229899  0.276382  0.358025  0.530864  0.111111
# 1805-Jefferson   0.504569  0.262944  0.232487  0.465909  0.458333  0.075758
#
#                  min  max   mean  median    1st_freq   2nd_freq    3rd_freq  \
# 1789-Washington   13  150  66.87    58.0  government     public     citizen
# 1793-Washington   19   64  36.75    32.0        oath     fellow     citizen
# 1797-Adams        10  810  69.84    45.0      people     nation  government
# 1801-Jefferson     4  270  47.15    38.0  government  principle         man
# 1805-Jefferson    15  139  52.93    41.0      public      state     citizen
#
#                 4th_freq 5th_freq
# 1789-Washington  present  country
# 1793-Washington     call    voice
# 1797-Adams       country    state
# 1801-Jefferson      good   fellow
# 1805-Jefferson    fellow     duty

# %% [markdown]
# Below, we can observe that, without preprocessing, the most frequent tokens consist of stopwords and punctuation marks

# %%
df_raw = pd.DataFrame.from_dict(data_raw, orient='index')
df_raw.select_dtypes('object').head()
# Out:
#                 1st_freq 2nd_freq 3rd_freq 4th_freq 5th_freq
# 1789-Washington      the       of        ,      and       to
# 1793-Washington      the       of        i        ,       to
# 1797-Adams             ,      the       of      and       to
# 1801-Jefferson       the        ,       of      and       to
# 1805-Jefferson       the        ,       of      and       to

# %% [markdown]
# # 4. Normalization

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(df.select_dtypes('number'))
df[df.select_dtypes('number').columns] = scaled
df.select_dtypes('number').head()
# Out:
#                      noun      verb       adj      past      pres    future  \
# 1789-Washington -0.586880 -0.321907  0.997758  1.239301 -1.322275 -0.070993
# 1793-Washington -0.757372 -0.258658  1.119702 -0.651301 -0.433522  2.260775
# 1797-Adams       2.004263 -2.361185  0.299132  2.398099 -1.972386 -1.292570
# 1801-Jefferson   0.145881 -0.330170  0.191339 -0.166585 -0.073346  0.504282
# 1805-Jefferson   0.478850  0.723210 -1.307403  0.982093 -0.919760 -0.308641
#
#                       min       max      mean    median
# 1789-Washington  1.479079  0.253096  2.904883  2.989814
# 1793-Washington  2.853342 -0.541096  0.366499  0.400105
# 1797-Adams       0.791948  6.348055  3.155182  1.694960
# 1801-Jefferson  -0.582315  1.361270  1.242966  0.997730
# 1805-Jefferson   1.937167  0.151513  1.730080  1.296543

# %%
scaler_raw = StandardScaler()
scaled_raw = scaler_raw.fit_transform(df_raw.select_dtypes('number'))
df_raw[df_raw.select_dtypes('number').columns] = scaled_raw
df_raw.select_dtypes('number').head()
# Out:
#                      noun      verb       adj      past      pres    future  \
# 1789-Washington -0.584785 -0.330420  1.003492  1.240356 -1.324357 -0.070390
# 1793-Washington -1.277802 -0.255490  1.695019 -0.650550 -0.435082  2.265301
# 1797-Adams       2.019308 -2.359543  0.269381  2.399340 -1.974850 -1.294022
# 1801-Jefferson   0.167965 -0.327054  0.161939 -0.165757 -0.074694  0.505853
# 1805-Jefferson   0.468635  0.727091 -1.297381  0.983106 -0.921606 -0.308437
#
#                       min       max      mean    median
# 1789-Washington  1.478977  0.194560  2.777200  2.955934
# 1793-Washington  2.849547 -0.604789  0.322265  0.398601
# 1797-Adams       0.793692  6.329099  3.351410  1.953058
# 1801-Jefferson  -0.576878  1.300636  1.345360  0.950182
# 1805-Jefferson   1.935834  0.083023  1.836838  1.251045

# %% [markdown]
# # 5. Word Embedding (Word2Vec)

# %%
model = Word2Vec(data_w2v, min_count=1, vector_size=5, sg=1)

embeddings = []
for i in range(df.shape[0]):
  words = df.select_dtypes('object').iloc[i].values
  emb = []
  for w in words:
    emb += list(model.wv[w])
  embeddings.append(emb)
embeddings = np.array(embeddings)
for attr in range(embeddings.shape[1]):
  df[f'{attr}'] = embeddings[:, attr]
df = df.select_dtypes('number')
df.head()
# Out:
#                      noun      verb       adj      past      pres    future  \
# 1789-Washington -0.586880 -0.321907  0.997758  1.239301 -1.322275 -0.070993
# 1793-Washington -0.757372 -0.258658  1.119702 -0.651301 -0.433522  2.260775
# 1797-Adams       2.004263 -2.361185  0.299132  2.398099 -1.972386 -1.292570
# 1801-Jefferson   0.145881 -0.330170  0.191339 -0.166585 -0.073346  0.504282
# 1805-Jefferson   0.478850  0.723210 -1.307403  0.982093 -0.919760 -0.308641
#
#                       min       max      mean    median  ...        15  \
# 1789-Washington  1.479079  0.253096  2.904883  2.989814  ... -0.378656
# 1793-Washington  2.853342 -0.541096  0.366499  0.400105  ... -0.480206
# 1797-Adams       0.791948  6.348055  3.155182  1.694960  ... -0.358406
# 1801-Jefferson  -0.582315  1.361270  1.242966  0.997730  ... -0.356550
# 1805-Jefferson   1.937167  0.151513  1.730080  1.296543  ... -1.629942
#
#                        16        17        18        19        20        21  \
# 1789-Washington  0.740103  0.976573 -0.866303  0.463789 -0.358406  0.836906
# 1793-Washington  0.928520  0.695885 -1.106410  0.216744 -0.002661  0.991658
# 1797-Adams       0.836906  1.089879 -0.635956  0.540957 -1.439569  0.643511
# 1801-Jefferson   0.603570  1.175406 -0.699271  0.849161 -1.629942  1.022455
# 1805-Jefferson   1.022455  0.996220 -0.439790 -0.265505 -0.601932  0.208415
#
#                        22        23        24
# 1789-Washington  1.089879 -0.635956  0.540957
# 1793-Washington  0.904866 -0.899023  0.373025
# 1797-Adams       0.264713 -1.345140  0.674462
# 1801-Jefferson   0.996220 -0.439790 -0.265505
# 1805-Jefferson   0.867257 -1.438185  0.653744
#
# [5 rows x 35 columns]

# %%
model_raw = Word2Vec(data_w2v_raw, min_count=1, vector_size=5, sg=1)

embeddings_raw = []
for i in range(df_raw.shape[0]):
  words = df_raw.select_dtypes('object').iloc[i].values
  emb = []
  for w in words:
    emb += list(model_raw.wv[w])
  embeddings_raw.append(emb)
embeddings_raw = np.array(embeddings_raw)
for attr in range(embeddings_raw.shape[1]):
  df_raw[f'{attr}'] = embeddings_raw[:, attr]
df_raw = df_raw.select_dtypes('number')
df_raw.head()
# Out:
#                      noun      verb       adj      past      pres    future  \
# 1789-Washington -0.584785 -0.330420  1.003492  1.240356 -1.324357 -0.070390
# 1793-Washington -1.277802 -0.255490  1.695019 -0.650550 -0.435082  2.265301
# 1797-Adams       2.019308 -2.359543  0.269381  2.399340 -1.974850 -1.294022
# 1801-Jefferson   0.167965 -0.327054  0.161939 -0.165757 -0.074694  0.505853
# 1805-Jefferson   0.468635  0.727091 -1.297381  0.983106 -0.921606 -0.308437
#
#                       min       max      mean    median  ...        15  \
# 1789-Washington  1.478977  0.194560  2.777200  2.955934  ... -0.106616
# 1793-Washington  2.849547 -0.604789  0.322265  0.398601  ... -0.791904
# 1797-Adams       0.793692  6.329099  3.351410  1.953058  ... -0.106616
# 1801-Jefferson  -0.576878  1.300636  1.345360  0.950182  ... -0.106616
# 1805-Jefferson   1.935834  0.083023  1.836838  1.251045  ... -0.106616
#
#                        16        17        18        19        20        21  \
# 1789-Washington  0.254264  0.771636  0.048364 -1.449779 -0.810487  0.217499
# 1793-Washington  0.301797  0.997741  0.109041 -1.152525 -0.810487  0.217499
# 1797-Adams       0.254264  0.771636  0.048364 -1.449779 -0.810487  0.217499
# 1801-Jefferson   0.254264  0.771636  0.048364 -1.449779 -0.810487  0.217499
# 1805-Jefferson   0.254264  0.771636  0.048364 -1.449779 -0.810487  0.217499
#
#                        22        23        24
# 1789-Washington  0.927087 -0.056826 -1.251179
# 1793-Washington  0.927087 -0.056826 -1.251179
# 1797-Adams       0.927087 -0.056826 -1.251179
# 1801-Jefferson   0.927087 -0.056826 -1.251179
# 1805-Jefferson   0.927087 -0.056826 -1.251179
#
# [5 rows x 35 columns]

# %% [markdown]
# # 6. Generating Target for Training

# %%
average_inflation = [2.99, 6.42, 0.0, -2.03, 1.26, 6.08, -4.52, -3.99, -3.25, -1.55, -2.51, 3.39, -2.43, -3.32, 0.33, 0.0,
 3.1, 0.29, 16.66, -4.43, -3.08, -3.28, -0.72, -1.25, -1.31, -0.55, -1.18, 0.6, 0.87, 0.84, 2.13, 6.63,
 8.75, -0.56, -0.58, -6.62, 2.59, 0.52, 5.19, 7.23, 2.92, 1.29, 1.56, 1.31, 3.89, 4.88, 8.09, 10.67,
 4.31, 3.61, 3.90, 2.66, 2.49, 2.48, 2.38, 2.08, 1.28, 2.54, 6.58]

df['inflation'] = average_inflation
df_raw['inflation'] = average_inflation
df['inflation'].describe()
# Out:
# count    59.000000
# mean      1.654746
# std       4.080609
# min      -6.620000
# 25%      -0.950000
# 50%       1.290000
# 75%       3.500000
# max      16.660000
# Name: inflation, dtype: float64

# %% [markdown]
# # 7. Dimensionality Reduction (tSNE)

# %%
tsne = TSNE(n_components=3)
data = tsne.fit_transform(df[df.columns[:-1]])
data = pd.DataFrame(data)
data['target'] = df[df.columns[-1]].values
data.head()
# Out:
#            0           1          2  target
# 0   9.325642  116.695900  82.169220    2.99
# 1  41.731297   83.989624  37.317051    6.42
# 2 -90.819420   29.960852 -14.669362    0.00
# 3 -74.966400  -34.594482 -25.349226   -2.03
# 4 -93.853081  -98.170319   2.542092    1.26

# %%
tsne_raw = TSNE(n_components=3)
data_raw = tsne_raw.fit_transform(df_raw[df_raw.columns[:-1]])
data_raw = pd.DataFrame(data_raw)
data_raw['target'] = df_raw[df_raw.columns[-1]].values
data_raw.head()
# Out:
#             0           1          2  target
# 0  -18.627115  111.067673 -80.688667    2.99
# 1  -72.231529   64.095329  -3.084186    6.42
# 2 -107.044403   80.322861  52.702499    0.00
# 3   46.619778   55.121151 -47.848160   -2.03
# 4  -63.893200   13.676625 -54.740559    1.26

# %% [markdown]
# # 8. Training Model

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data[data.columns[:-1]],
    data['target'],
    test_size=0.2,
)

regressor = SVR()
regressor.fit(X_train, y_train)
train_pred = regressor.predict(X_train)
train_loss = mean_squared_error(y_train, train_pred)
test_pred = regressor.predict(X_test)
test_loss = mean_squared_error(y_test, test_pred)
print(f"Train Loss: {train_loss}, Test Loss: {test_loss}")
# Out:
# Train Loss: 15.999721409189839, Test Loss: 14.649146224041935

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data_raw[data_raw.columns[:-1]],
    data_raw['target'],
    test_size=0.2,
)

regressor = SVR()
regressor.fit(X_train, y_train)
train_pred = regressor.predict(X_train)
train_loss = mean_squared_error(y_train, train_pred)
test_pred = regressor.predict(X_test)
test_loss = mean_squared_error(y_test, test_pred)
print(f"Train Loss: {train_loss}, Test Loss: {test_loss}")
# Out:
# Train Loss: 9.13347218162066, Test Loss: 33.45190290786114

# %%
inflation_class = []
for i in average_inflation:
  if i > 0:
    inflation_class.append(1)
  elif i < 0:
    inflation_class.append(-1)
  else:
    inflation_class.append(0)

data['target'] = inflation_class
data.groupby('target')['target'].count()
# Out:
# target
# -1    19
#  0     2
#  1    38
# Name: target, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data[data.columns[:-1]],
    data['target'],
    test_size=0.2,
    stratify=data['target']
)

classify = SVC(C=0.005, gamma= 0.005, kernel= 'rbf') # using parameters from GridSearchCV below
classify.fit(X_train, y_train)
train_pred = classify.predict(X_train)
train_loss = f1_score(y_train, train_pred, average='micro')
test_pred = classify.predict(X_test)
test_loss = f1_score(y_test, test_pred, average='micro')
print(f"Train Loss: {train_loss}, Test Loss: {test_loss}")
# Out:
# Train Loss: 0.6382978723404256, Test Loss: 0.6666666666666666

# %%
### Search took 34 mins
# model = SVC()
# params = {
#     'gamma': [0.005, 0.01, 0.02, 1, 2, 5],
#     'kernel': ['rbf', 'linear', 'sigmoid'],
#     'C': [0.005, 0.01, 0.02, 1, 2, 5]
# }

# cv = RepeatedKFold(n_splits=4)

# search = GridSearchCV(model, params, scoring='f1_micro', n_jobs=-1, cv=cv, verbose=3)

# result = search.fit(X_train, y_train)

# print('Best Score:', result.best_score_)
# print('Best Hyperparameters:', result.best_params_)

# ### Score: 0.6382575757575758
# ### Best Hyperparameters: {'C': 0.005, 'gamma': 0.005, 'kernel': 'rbf'}
# Out:
# Fitting 40 folds for each of 108 candidates, totalling 4320 fits
# [CV 1/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.833 total time=   0.0s[CV 4/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.364 total time=   0.0s[CV 3/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.750 total time=   0.0s
#
# [CV 7/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 6/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 8/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 5/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
#
# [CV 9/40] END .C=0.005, gamma=0.005, kernel=rbf;, score=0.333 total time=   0.0s
# [CV 10/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 14/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 11/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 13/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 12/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.818 total time=   0.0s[CV 15/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.667 total time=   0.0s
#
# [CV 16/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 17/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.333 total time=   0.0s
# [CV 18/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 19/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 21/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 23/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 25/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 24/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 20/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 22/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 26/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 27/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 28/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.455 total time=   0.0s
# [CV 29/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 30/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 31/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 32/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 33/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 35/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 34/40] END C=0.005, gamma=0.005, kernel=rbf;, score=0.750 total time=   0.0s
# [CV
40] END C=0.005, gamma=0.01, kernel=linear;, score=0.636 total time=   0.0s
#
# [CV 39/40] END .C=0.005, gamma=0.01, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 13/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.583 total time=   0.0s
# [CV 6/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 21/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.583 total time=   0.0s
# [CV 13/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 39/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.583 total time=   0.0s
# [CV 40/40] END .C=0.005, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 7/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 22/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.667 total time=   0.0s
# [CV 17/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 14/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 40/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.364 total time=   0.0s
# [CV 29/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.667 total time=   0.0s
# [CV 8/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 23/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.500 total time=   0.0s
# [CV 14/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.500 total time=   0.0s
# [CV 25/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 15/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 33/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 24/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.727 total time=   0.0s
# [CV 1/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 26/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.833 total time=   0.0s
# [CV 16/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 18/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 34/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 2/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 9/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.333 total time=   0.0s
# [CV 27/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 17/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.333 total time=   0.0s
# [CV 15/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.417 total time=   0.0s[CV 35/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 3/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 10/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 18/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 19/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 36/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 28/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 30/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.750 total time=   0.1s
# [CV 4/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.364 total time=   0.0s
# [CV 11/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.833 total time=   0.0s
#
# [CV 19/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 37/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 20/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 5/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 12/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 29/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 20/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 38/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 6/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.667 total time=   0.0s[CV 13/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.583 total time=   0.0s
#
# [CV 21/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 30/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 21/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.583 total time=   0.0s[CV 31/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.583 total time=   0.0s
#
# [CV 39/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 14/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.500 total time=   0.0s[CV 7/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.667 total time=   0.0s
#
# [CV 22/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 31/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 16/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.273 total time=   0.0s
# [CV 22/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 40/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s[CV 15/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.667 total time=   0.0s
#
# [CV 8/40] END ..C=0.005, gamma=0.02, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 32/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 23/40] END C=0.005, gamma=0.01, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 32/40] END C=0.005, gamma=0.01, kernel=linear;, score=0.545 total time=   0.0s
# [CV 25/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 16/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 23/40] END .C=0.005, gamma=0.02, kernel=rbf;, score=0.583 total time=   0.0s
# [CV
kernel=rbf;, score=0.583 total time=   0.0s
# [CV 40/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.364 total time=   0.0s
# [CV 34/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 21/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 18/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 24/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.727 total time=   0.0s
# [CV 11/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 11/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.333 total time=   0.0s
# [CV 33/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 35/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 22/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 1/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.833 total time=   0.0s[CV 12/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.818 total time=   0.0s
#
# [CV 19/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 34/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 25/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.750 total time=   0.0s
# [CV 12/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.818 total time=   0.0s
# [CV 36/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 23/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 13/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 35/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 20/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 2/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.583 total time=   0.0s[CV 37/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.750 total time=   0.0s
#
# [CV 26/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.250 total time=   0.0s
# [CV 13/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.583 total time=   0.0s
# [CV 24/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 14/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 36/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 21/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 38/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 14/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.500 total time=   0.0s
# [CV 15/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 27/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.500 total time=   0.0s
# [CV 3/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 37/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 22/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 39/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 16/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 4/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.364 total time=   0.0s
# [CV 15/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.417 total time=   0.0s
# [CV 38/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 28/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.455 total time=   0.0s
# [CV 23/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 40/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 9/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.333 total time=   0.0s
# [CV 39/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 5/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 16/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.273 total time=   0.0s
# [CV 24/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 29/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.667 total time=   0.0s
# [CV 1/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.833 total time=   0.0s
# [CV 40/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 6/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 25/40] END .C=0.005, gamma=1, kernel=linear;, score=0.750 total time=   0.0s
# [CV 25/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 17/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 2/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 10/40] END .C=0.005, gamma=1, kernel=linear;, score=0.583 total time=   0.0s
# [CV 30/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.750 total time=   0.0s
# [CV 7/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 26/40] END .C=0.005, gamma=1, kernel=linear;, score=0.250 total time=   0.0s[CV 18/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 3/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.750 total time=   0.0s
#
# [CV 1/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.833 total time=   0.0s[CV 26/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.833 total time=   0.0s
#
# [CV 11/40] END .C=0.005, gamma=1, kernel=linear;, score=0.333 total time=   0.0s
# [CV 19/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 8/40] END C=0.005, gamma=0.02, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 27/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 12/40] END .C=0.005, gamma=1, kernel=linear;, score=0.818 total time=   0.0s
# [CV 31/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.583 total time=   0.0s
# [CV 2/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.583 total time=   0.0s
# [CV 4/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.364 total time=   0.0s
# [CV 20/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 13/40] END .C=0.005, gamma=1, kernel=linear;, score=0.583 total time=   0.0s[CV 28/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.455 total time=   0.0s
#
# [CV 33/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 5/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 3/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.750 total time=   0.0s
# [CV 21/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 32/40] END C=0.005, gamma=0.02, kernel=linear;, score=0.545 total time=   0.0s
# [CV 14/40] END .C=0.005, gamma=1, kernel=linear;, score=0.500 total time=   0.0s
# [CV 34/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 29/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 6/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 4/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.364 total time=   0.0s
# [CV 22/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 35/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 30/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 15/40] END .C=0.005, gamma=1, kernel=linear;, score=0.417 total time=   0.0s
# [CV 7/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 5/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.583 total time=   0.0s
# [CV 23/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 36/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 9/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.333 total time=   0.0s
# [CV 16/40] END .C=0.005, gamma=1, kernel=linear;, score=0.273 total time=   0.0s
# [CV 31/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 8/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 27/40] END .C=0.005, gamma=1, kernel=linear;, score=0.500 total time=   0.1s
# [CV 24/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 6/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.417 total time=   0.0s
# [CV 37/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 17/40] END .C=0.005, gamma=1, kernel=linear;, score=0.333 total time=   0.0s
# [CV 32/40] END ....C=0.005, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s[CV 10/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 9/40] END .C=0.005, gamma=1, kernel=sigmoid;, score=0.333 total time=   0.0s
#
# [CV 25/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 38/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 18/40] END .C=0.005, gamma=1, kernel=linear;, score=0.750 total time=   0.0s
# [CV 7/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.667 total time=   0.0s
# [CV 10/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 26/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.833 total time=   0.0s
# [CV 39/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 11/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 19/40] END .C=0.005, gamma=1, kernel=linear;, score=0.750 total time=   0.0s[CV 25/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.750 total time=   0.0s
#
# [CV 8/40] END ..C=0.005, gamma=1, kernel=linear;, score=0.636 total time=   0.0s
# [CV 11/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.833 total time=   0.0s
# [CV 40/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 28/40] END .C=0.005, gamma=1, kernel=linear;, score=0.455 total time=   0.0s
# [CV 20/40] END .C=0.005, gamma=1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 27/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 26/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 12/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 12/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 1/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.833 total time=   0.0s
# [CV 1/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.833 total time=   0.0s
# [CV 21/40] END .C=0.005, gamma=1, kernel=linear;, score=0.583 total time=   0.0s
# [CV 13/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 27/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 2/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 2/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.583 total time=   0.0s
# [CV 13/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 28/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 22/40] END .C=0.005, gamma=1, kernel=linear;, score=0.667 total time=   0.0s
# [CV 29/40] END .C=0.005, gamma=1, kernel=linear;, score=0.667 total time=   0.0s
# [CV 28/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.455 total time=   0.0s[CV 14/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.500 total time=   0.0s
#
# [CV 3/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 3/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.750 total time=   0.0s
# [CV 23/40] END .C=0.005, gamma=1, kernel=linear;, score=0.500 total time=   0.0s
# [CV 14/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 29/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.364 total time=   0.0s
# [CV 4/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.364 total time=   0.0s
# [CV 30/40] END .C=0.005, gamma=1, kernel=linear;, score=0.750 total time=   0.0s[CV 15/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 29/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.667 total time=   0.0s[CV 24/40] END .C=0.005, gamma=1, kernel=linear;, score=0.727 total time=   0.0s
#
# [CV 15/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.667 total time=   0.0s
#
# [CV 30/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 5/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 16/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 5/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.583 total time=   0.0s
# [CV 16/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 30/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 6/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 31/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 6/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.417 total time=   0.0s
# [CV 7/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 32/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 33/40] END .C=0.005, gamma=2, kernel=linear;, score=0.583 total time=   0.0s
# [CV 31/40] END .C=0.005, gamma=1, kernel=linear;, score=0.583 total time=   0.0s
# [CV 17/40] END .C=0.005, gamma=2, kernel=linear;, score=0.333 total time=   0.0s[CV 7/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.667 total time=   0.0s
# [CV 31/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 8/40] END .....C=0.005, gamma=2, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 33/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
#
# [CV 17/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.333 total time=   0.0s
# [CV 34/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 18/40] END .C=0.005, gamma=2, kernel=linear;, score=0.750 total time=   0.0s[CV 8/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.636 total time=   0.0s
# [CV 9/40] END .C=0.005, gamma=2, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 34/40] END .C=0.005, gamma=2, kernel=linear;, score=0.750 total time=   0.0s
#
# [CV 35/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.500 total time=   0.0s
# [CV 18/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 32/40] END .C=0.005, gamma=1, kernel=linear;, score=0.545 total time=   0.0s[CV 10/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
#
# [CV 32/40] END C=0.005, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 9/40] END ..C=0.005, gamma=2, kernel=linear;, score=0.333 total time=   0.0s
# [CV 19/40] END .C=0.005, gamma=2, kernel=linear;, score=0.750 total time=   0.0s
# [CV 36/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 11/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.833 total time=   0.0s
# [CV 10/40] END .C=0.005, gamma=2, kernel=linear;, score=0.583 total time=   0.0s
# [CV 35/40] END .C=0.005, gamma=2, kernel=linear;, score=0.500 total time=   0.0s
# [CV 19/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 37/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 12/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 20/40] END .C=0.005, gamma=2, kernel=linear;, score=0.727 total time=   0.0s
# [CV 25/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 33/40] END .C=0.005, gamma=1, kernel=linear;, score=0.583 total time=   0.0s
# [CV 38/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 36/40] END .C=0.005, gamma=2, kernel=linear;, score=0.727 total time=   0.0s
# [CV 13/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 20/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 21/40] END .C=0.005, gamma=2, kernel=linear;, score=0.583 total time=   0.0s
# [CV 11/40] END .C=0.005, gamma=2, kernel=linear;, score=0.333 total time=   0.0s
# [CV 26/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.833 total time=   0.0s
# [CV 39/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 14/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 22/40] END .C=0.005, gamma=2, kernel=linear;, score=0.667 total time=   0.0s
# [CV 27/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 12/40] END .C=0.005, gamma=2, kernel=linear;, score=0.818 total time=   0.0s
# [CV 37/40] END .C=0.005, gamma=2, kernel=linear;, score=0.750 total time=   0.0s
# [CV 40/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 15/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 23/40] END .C=0.005, gamma=2, kernel=linear;, score=0.500 total time=   0.0s
# [CV 13/40] END .C=0.005, gamma=2, kernel=linear;, score=0.583 total time=   0.0s
# [CV 21/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 38/40] END .C=0.005, gamma=2, kernel=linear;, score=0.667 total time=   0.0s
# [CV 16/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 24/40] END .C=0.005, gamma=2, kernel=linear;, score=0.727 total time=   0.0s
# [CV 34/40] END .C=0.005, gamma=1, kernel=linear;, score=0.750 total time=   0.0s
# [CV 1/40] END .....C=0.005, gamma=5, kernel=rbf;, score=0.833 total time=   0.0s[CV 14/40] END .C=0.005, gamma=2, kernel=linear;, score=0.500 total time=   0.0s
#
# [CV 22/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 28/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 17/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.333 total time=   0.0s[CV 25/40] END .C=0.005, gamma=2, kernel=linear;, score=0.750 total time=   0.0s
#
# [CV 2/40] END .....C=0.005, gamma=5, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 15/40] END .C=0.005, gamma=2, kernel=linear;, score=0.417 total time=   0.0s
# [CV 39/40] END .C=0.005, gamma=2, kernel=linear;, score=0.583 total time=   0.0s
# [CV 35/40] END .C=0.005, gamma=1, kernel=linear;, score=0.500 total time=   0.0s
# [CV 29/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.667 total time=   0.0s
# [CV 26/40] END .C=0.005, gamma=2, kernel=linear;, score=0.250 total time=   0.0s[CV 18/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.750 total time=   0.0s
#
# [CV 3/40] END .....C=0.005, gamma=5, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 16/40] END .C=0.005, gamma=2, kernel=linear;, score=0.273 total time=   0.0s
# [CV 30/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 23/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.583 total time=   0.0s[CV 27/40] END .C=0.005, gamma=2, kernel=linear;, score=0.500 total time=   0.0s
#
# [CV 19/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 40/40] END .C=0.005, gamma=2, kernel=linear;, score=0.364 total time=   0.0s
# [CV 4/40] END .....C=0.005, gamma=5, kernel=rbf;, score=0.364 total time=   0.0s
# [CV 36/40] END .C=0.005, gamma=1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 31/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 17/40] END ....C=0.005, gamma=5, kernel=rbf;, score=0.333 total time=   0.0s
# [CV 28/40] END .C=0.005, gamma=2, kernel=linear;, score=0.455 total time=   0.0s
# [CV 5/40] END .....C=0.005, gamma=5, kernel=rbf;, score=0.583 total time=   0.0s
# [CV 20/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 37/40] END .C=0.005, gamma=1, kernel=linear;, score=0.750 total time=   0.0s[CV 32/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 18/40] END ....C=0.005, gamma=5, kernel=rbf;, score=0.750 total time=   0.0s
#
# [CV 24/40] END ....C=0.005, gamma=2, kernel=rbf;, score=0.727 total time=   0.0s[CV 29/40] END .C=0.005, gamma=2, kernel=linear;, score=0.667 total time=   0.0s
#
# [CV 6/40] END .....C=0.005, gamma=5, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 1/40] END .C=0.005, gamma=2, kernel=sigmoid;, score=0.833 total time=   0.0s
# [CV 21/40] END C=0.005, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# ...
# [CV 7/40] END ......C=5, gamma=2, kernel=linear;, score=0.667 total time= 1.0min
# [CV 6/40] END ......C=5, gamma=2, kernel=linear;, score=0.417 total time=  15.2s
# [CV 13/40] END .....C=5, gamma=2, kernel=linear;, score=0.583 total time=  45.2s
# [CV 38/40] END .....C=5, gamma=1, kernel=linear;, score=0.667 total time= 1.1min
# [CV 16/40] END .....C=5, gamma=2, kernel=linear;, score=0.273 total time=   8.2s
# [CV 36/40] END .....C=5, gamma=1, kernel=linear;, score=0.727 total time=  36.4s
# [CV 4/40] END ......C=5, gamma=2, kernel=linear;, score=0.364 total time=  41.8s
# [CV 10/40] END .....C=5, gamma=2, kernel=linear;, score=0.583 total time=  38.0s
# [CV 23/40] END .....C=5, gamma=2, kernel=linear;, score=0.500 total time=  24.0s
# [CV 8/40] END ......C=5, gamma=2, kernel=linear;, score=0.636 total time=  46.2s
# [CV 17/40] END .....C=5, gamma=2, kernel=linear;, score=0.333 total time=  43.0s
# [CV 19/40] END .....C=5, gamma=2, kernel=linear;, score=0.750 total time=  40.9s
# [CV 21/40] END .....C=5, gamma=2, kernel=linear;, score=0.583 total time=  33.5s
# [CV 39/40] END .....C=5, gamma=1, kernel=linear;, score=0.583 total time=  41.7s
# [CV 40/40] END .....C=5, gamma=1, kernel=linear;, score=0.364 total time=   5.7s
# [CV 20/40] END .....C=5, gamma=2, kernel=linear;, score=0.727 total time=  28.2s
# [CV 25/40] END .....C=5, gamma=2, kernel=linear;, score=0.750 total time=  46.8s
# [CV 29/40] END .....C=5, gamma=2, kernel=linear;, score=0.667 total time=  25.1s
# [CV 18/40] END .....C=5, gamma=2, kernel=linear;, score=0.750 total time=  40.8s
# [CV 24/40] END .....C=5, gamma=2, kernel=linear;, score=0.727 total time=  56.6s
# [CV 27/40] END .....C=5, gamma=2, kernel=linear;, score=0.500 total time=  56.2s
# [CV 26/40] END .....C=5, gamma=2, kernel=linear;, score=0.250 total time=  24.6s
# [CV 30/40] END .....C=5, gamma=2, kernel=linear;, score=0.750 total time=  25.3s
# [CV 31/40] END .....C=5, gamma=2, kernel=linear;, score=0.583 total time=  32.0s
# [CV 28/40] END .....C=5, gamma=2, kernel=linear;, score=0.455 total time=  21.8s
# [CV 33/40] END .....C=5, gamma=2, kernel=linear;, score=0.583 total time=  37.9s
# [CV 22/40] END .....C=5, gamma=2, kernel=linear;, score=0.667 total time= 1.3min
# [CV 14/40] END .....C=5, gamma=2, kernel=linear;, score=0.500 total time= 2.1min
# [CV 40/40] END .....C=5, gamma=2, kernel=linear;, score=0.364 total time=   5.7s
# [CV 1/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 2/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 3/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 4/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.273 total time=   0.0s
# [CV 5/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 6/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.417 total time=   0.0s
# [CV 7/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 8/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 9/40] END .....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 10/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 11/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 12/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 13/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 14/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 15/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 16/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 17/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 18/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 19/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 20/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.364 total time=   0.0s
# [CV 21/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 22/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.417 total time=   0.0s
# [CV 23/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 24/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 25/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 26/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.167 total time=   0.0s
# [CV 27/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 28/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.364 total time=   0.0s
# [CV 29/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 30/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 31/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 32/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 33/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 34/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 35/40] END ....C=5, gamma=2, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV
# [CV 9/40] END ......C=5, gamma=5, kernel=linear;, score=0.333 total time=  41.6s
# [CV 2/40] END ......C=5, gamma=5, kernel=linear;, score=0.583 total time=  13.0s
# [CV 13/40] END .....C=5, gamma=5, kernel=linear;, score=0.583 total time=  44.1s
# [CV 17/40] END .....C=5, gamma=5, kernel=linear;, score=0.333 total time=  44.3s
# [CV 38/40] END .....C=5, gamma=2, kernel=linear;, score=0.667 total time= 1.0min
# [CV 5/40] END ......C=5, gamma=5, kernel=linear;, score=0.583 total time= 1.0min
# [CV 21/40] END .....C=5, gamma=5, kernel=linear;, score=0.583 total time=  34.7s
# [CV 29/40] END .....C=5, gamma=5, kernel=linear;, score=0.667 total time=  25.5s
# [CV 25/40] END .....C=5, gamma=5, kernel=linear;, score=0.750 total time=  46.7s
# [CV 6/40] END ......C=5, gamma=5, kernel=linear;, score=0.417 total time=  15.9s
# [CV 10/40] END .....C=5, gamma=5, kernel=linear;, score=0.583 total time=  38.4s
# [CV 18/40] END .....C=5, gamma=5, kernel=linear;, score=0.750 total time=  42.2s
# [CV 11/40] END .....C=5, gamma=5, kernel=linear;, score=0.333 total time=  15.2s
# [CV 30/40] END .....C=5, gamma=5, kernel=linear;, score=0.750 total time=  24.4s
# [CV 26/40] END .....C=5, gamma=5, kernel=linear;, score=0.250 total time=  26.1s
# [CV 3/40] END ......C=5, gamma=5, kernel=linear;, score=0.750 total time=  59.7s
# [CV 12/40] END .....C=5, gamma=5, kernel=linear;, score=0.636 total time=  13.7s
# [CV 19/40] END .....C=5, gamma=5, kernel=linear;, score=0.750 total time=  39.9s
# [CV 31/40] END .....C=5, gamma=5, kernel=linear;, score=0.583 total time=  31.9s
# [CV 22/40] END .....C=5, gamma=5, kernel=linear;, score=0.667 total time= 1.3min
# [CV 7/40] END ......C=5, gamma=5, kernel=linear;, score=0.667 total time= 1.0min
# [CV 4/40] END ......C=5, gamma=5, kernel=linear;, score=0.364 total time=  39.8s
# [CV 33/40] END .....C=5, gamma=5, kernel=linear;, score=0.583 total time=  38.4s
# [CV 20/40] END .....C=5, gamma=5, kernel=linear;, score=0.727 total time=  28.5s
# [CV 1/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 2/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 3/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 4/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.273 total time=   0.0s
# [CV 5/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 6/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.417 total time=   0.0s
# [CV 7/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 8/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 9/40] END .....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 10/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 11/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 12/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 13/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 14/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 15/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 16/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 17/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 18/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 19/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 20/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.364 total time=   0.0s
# [CV 21/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.500 total time=   0.0s
# [CV 22/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.417 total time=   0.0s
# [CV 23/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 24/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 25/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 26/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.167 total time=   0.0s
# [CV 27/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 28/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.364 total time=   0.0s
# [CV 29/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 30/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 31/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 32/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 33/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 34/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.750 total time=   0.0s
# [CV 35/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 36/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.273 total time=   0.0s
# [CV 37/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.333 total time=   0.0s
# [CV 38/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 39/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.583 total time=   0.0s
# [CV 40/40] END ....C=5, gamma=5, kernel=sigmoid;, score=0.455 total time=   0.0s
# [CV 27/40] END .....C=5, gamma=5, kernel=linear;, score=0.500 total time=  58.7s
# [CV 32/40] END .....C=5, gamma=5, kernel=linear;, score=0.545 total time=  32.1s
# [CV 23/40] END .....C=5, gamma=5, kernel=linear;, score=0.500 total time=  24.9s
# [CV 14/40] END .....C=5, gamma=5, kernel=linear;, score=0.500 total time= 2.1min
# [CV 28/40] END .....C=5, gamma=5, kernel=linear;, score=0.455 total time=  21.8s
# [CV 8/40] END ......C=5, gamma=5, kernel=linear;, score=0.636 total time=  44.9s
# [CV 37/40] END .....C=5, gamma=5, kernel=linear;, score=0.750 total time=  40.9s
# [CV 34/40] END .....C=5, gamma=5, kernel=linear;, score=0.750 total time=  37.7s
# [CV 15/40] END .....C=5, gamma=5, kernel=linear;, score=0.417 total time=  14.3s
# [CV 16/40] END .....C=5, gamma=5, kernel=linear;, score=0.273 total time=   5.3s
# [CV 24/40] END .....C=5, gamma=5, kernel=linear;, score=0.727 total time=  41.2s
# [CV 35/40] END .....C=5, gamma=5, kernel=linear;, score=0.500 total time=  21.4s
# [CV 38/40] END .....C=5, gamma=5, kernel=linear;, score=0.667 total time=  35.3s
# [CV 36/40] END .....C=5, gamma=5, kernel=linear;, score=0.727 total time=  20.0s
# [CV 39/40] END .....C=5, gamma=5, kernel=linear;, score=0.583 total time=  22.4s
# [CV 40/40] END .....C=5, gamma=5, kernel=linear;, score=0.364 total time=   3.0s
# Best Score: 0.6382575757575758
# Best Hyperparameters: {'C': 0.005, 'gamma': 0.005, 'kernel': 'rbf'}
